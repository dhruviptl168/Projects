# %% [markdown]
# **Sum List Using Reduce**

# %%
from functools import reduce

numbers = list(map(int, input("Enter numbers: ").split(",")))

positive_numbers = list(filter(lambda x: x > 0, numbers))

double_numbers = list(map(lambda x: x * 2, positive_numbers))

total = reduce(lambda a, b: a + b, double_numbers)


print("Original List:", numbers)
print("Positive Numbers:", positive_numbers)
print("After Map (Double Numbers):", double_numbers)
print("Sum using Reduce:", total)
# Out:
# Enter numbers: 1,2,3,-3,4,-4,2,5
# Original List: [1, 2, 3, -3, 4, -4, 2, 5]
# Positive Numbers: [1, 2, 3, 4, 2, 5]
# After Map (Double Numbers): [2, 4, 6, 8, 4, 10]
# Sum using Reduce: 34
